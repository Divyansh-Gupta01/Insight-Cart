# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from app.services.cleaner import load_and_clean

from app.services.cleaner import sort_theSample

CSV_PATH =  "cart_insight_supermarket_2025_profit_tax.csv"


print(CSV_PATH)
df = load_and_clean(CSV_PATH)
df.head()
# Out:
# cart_insight_supermarket_2025_profit_tax.csv
# E:\Insigth_Cart\data\cart_insight_supermarket_2025_profit_tax.csv
# Duplicates removed: 0
# Invalid business rows removed: 0
# Day name mismatches: 0
# Gross sales errors removed: 0
# Net sales errors removed: 0
# Stock logic errors removed: 0
# Low stock flag errors removed: 0
#
# Clean shape: (85771, 39)
#   transaction_id   bill_number       date      time day_name  is_weekend  \
# 0   T20250000001  B20250000001 2025-04-13  20:48:32   Sunday           1
# 1   T20250000002  B20250000001 2025-04-13  20:48:32   Sunday           1
# 2   T20250000003  B20250000002 2025-12-15  16:37:54   Monday           0
# 3   T20250000004  B20250000002 2025-12-15  16:37:54   Monday           0
# 4   T20250000005  B20250000002 2025-12-15  16:37:54   Monday           0
#
#    month  year festival_season weather_tag  ... payment_mode  \
# 0      4  2025            <NA>       Humid  ...          upi
# ...

# %%
print(sort_theSample(CSV_PATH))
# Out:
# e:\Insigth_Cart\app\services\cleaner.py:109: DtypeWarning: Columns (0: festival_season) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# True

# %%
df.groupby("bill_number")["payment_mode"].nunique().max()
# Out:
# np.int64(1)
