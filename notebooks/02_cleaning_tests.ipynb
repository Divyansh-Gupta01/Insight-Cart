# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from app.services.cleaner import load_and_clean


CSV_PATH =  "cart_insight_supermarket_2025_profit_tax.csv"


print(CSV_PATH)
df = load_and_clean(CSV_PATH)
df.head()
# Out:
# cart_insight_supermarket_2025_profit_tax.csv
# E:\Insigth_Cart\data\cart_insight_supermarket_2025_profit_tax.csv
#   transaction_id   bill_number        date      time   day_name  is_weekend  \
# 0   T20250000001  B20250000001  2025-01-01  10:15:14  Wednesday           0
# 1   T20250000002  B20250000002  2025-01-01  13:28:37  Wednesday           0
# 2   T20250000003  B20250000003  2025-01-01  12:46:29  Wednesday           0
# 3   T20250000004  B20250000004  2025-01-01  17:24:17  Wednesday           0
# 4   T20250000005  B20250000005  2025-01-01  21:14:43  Wednesday           0
#
#    month  year festival_season weather_tag  ... stock_after_sale  \
# 0      1  2025            <NA>        Cold  ...              235
# 1      1  2025            <NA>        Cold  ...              159
# 2      1  2025            <NA>    Pleasant  ...               98
# 3      1  2025            <NA>        Cold  ...              256
# 4      1  2025            <NA>        Cold  ...              276
#
#   reorder_level low_stock_flag dead_stock_flag promotion_type return_flag  \
# 0            60              0               0           none           0
# 1            40              0               0           none           0
# 2            30              0               0           none           0
# 3            60              0               0           none           0
# 4            70              0               0           none           0
#
#   return_reason basket_size sales_channel  supplier_id
# 0           NaN           7      in-store         S013
# 1           NaN          13      in-store         S058
# 2           NaN           8      in-store         S042
# 3           NaN           7      in-store         S028
# 4           NaN           5       offline         S008
#
# [5 rows x 53 columns]
